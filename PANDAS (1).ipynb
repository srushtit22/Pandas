# %%
import numpy as np
import pandas as pd

# %%
# create series
ser = pd.Series(np.random.random((10)))

# %%
ser
# Out:
# 0    0.076212
# 1    0.819245
# 2    0.925100
# 3    0.638151
# 4    0.826215
# 5    0.330231
# 6    0.408927
# 7    0.906556
# 8    0.681461
# 9    0.565542
# dtype: float64

# %%
print(type(ser))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# create DataFrame
newdf = pd.DataFrame(np.random.rand(5,2),index=np.arange(1,6))

# %%
newdf
# Out:
#           0         1
# 1  0.367595  0.322547
# 2  0.697139  0.113705
# 3  0.845097  0.700175
# 4  0.340580  0.930995
# 5  0.814641  0.602328

# %%
print(type(newdf))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Create the data
data = pd.DataFrame(
    {
      "Name" : ["sambhav","amaya","arushi","samyy"],
      "Age" : [23,20,21,22],
      "Sex": ["male","Female","Female","Female"]
    }
)

# %%
df= pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age     Sex
# 0  sambhav   23    male
# 1    amaya   20  Female
# 2   arushi   21  Female
# 3    samyy   22  Female

# %%
#data converted into excelsheet
df.to_csv('friends.csv')

# %%
#read the csv file
r = pd.read_csv('friends.csv')

# %%
r
# Out:
#    Unnamed: 0     Name  Age     Sex
# 0           0  sambhav   23    male
# 1           1    amaya   20  Female
# 2           2   arushi   21  Female
# 3           3    samyy   22  Female

# %%
# work with series age
df['Age']
# Out:
# 0    23
# 1    20
# 2    21
# 3    22
# Name: Age, dtype: int64

# %%
df[['Age','Sex']]
# Out:
#    Age     Sex
# 0   23    male
# 1   20  Female
# 2   21  Female
# 3   22  Female

# %%
df.index=[1 ,2,3,4]

# %%
df
# Out:
#       Name  Age     Sex
# 1  sambhav   23    male
# 2    amaya   20  Female
# 3   arushi   21  Female
# 4    samyy   22  Female

# %%
df['Age'].max()
# Out:
# 23

# %%
df['Age'].mean()
# Out:
# 21.5

# %%
df.describe()
# Out:
#              Age
# count   4.000000
# mean   21.500000
# std     1.290994
# min    20.000000
# 25%    20.750000
# 50%    21.500000
# 75%    22.250000
# max    23.000000

# %%
df.dtypes
# Out:
# Name    object
# Age      int64
# Sex     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 1 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   Sex     4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 128.0+ bytes

# %%
print(df.shape)
print(df.ndim)
print(df.size)
# Out:
# (4, 3)
# 2
# 12

# %%
df["Age"]>21
# Out:
# 1     True
# 2    False
# 3    False
# 4     True
# Name: Age, dtype: bool

# %%
df.reset_index()
# Out:
#    index     Name  Age     Sex
# 0      1  sambhav   23    male
# 1      2    amaya   20  Female
# 2      3   arushi   21  Female
# 3      4    samyy   22  Female

# %%
df.reset_index(drop=True)
# Out:
#       Name  Age     Sex
# 0  sambhav   23    male
# 1    amaya   20  Female
# 2   arushi   21  Female
# 3    samyy   22  Female

# %%
print(df.loc[3])
print(df.iloc[3])
# Out:
# Name    arushi
# Age         21
# Sex     Female
# Name: 3, dtype: object
# Name     samyy
# Age         22
# Sex     Female
# Name: 4, dtype: object

# %%
 df.loc[:, 'Name']
# Out:
# 1    sambhav
# 2      amaya
# 3     arushi
# 4      samyy
# Name: Name, dtype: object

# %%
df.iloc[: , 0]
# Out:
# 1    sambhav
# 2      amaya
# 3     arushi
# 4      samyy
# Name: Name, dtype: object

# %%
df.head(3)
# Out:
#       Name  Age     Sex
# 1  sambhav   23    male
# 2    amaya   20  Female
# 3   arushi   21  Female

# %%
df.tail(2)
# Out:
#      Name  Age     Sex
# 3  arushi   21  Female
# 4   samyy   22  Female

# %%
#You can even check the amount of memory used by each column with .memory_usage():


df.memory_usage()
# Out:
# Index    204
# Name      32
# Age       32
# Sex       32
# dtype: int64

# %%
#Sorting a pandas DataFrame


df.sort_values(by='Age', ascending=False)
# Out:
#       Name  Age     Sex
# 1  sambhav   23    male
# 4    samyy   22  Female
# 3   arushi   21  Female
# 2    amaya   20  Female

# %%
df
# Out:
#       Name  Age     Sex
# 1  sambhav   23    male
# 2    amaya   20  Female
# 3   arushi   21  Female
# 4    samyy   22  Female

# %%
# delete a row from dataframe
df.drop(1, inplace = True)

# %%
df
# Out:
#      Name  Age     Sex
# 2   amaya   20  Female
# 3  arushi   21  Female
# 4   samyy   22  Female

# %%
Arya = pd.Series(data=['Arya', 34, 'Female'], index=df.columns)

# %%
df.append(Arya, ignore_index =True)
# Out:
# <ipython-input-39-dfd60349c6ce>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(Arya, ignore_index =True)
#      Name  Age     Sex
# 0   amaya   20  Female
# 1  arushi   21  Female
# 2   samyy   22  Female
# 3    Arya   34  Female
